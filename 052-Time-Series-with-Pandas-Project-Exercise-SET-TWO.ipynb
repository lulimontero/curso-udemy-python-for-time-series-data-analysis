# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Time Series with Pandas Project Exercise
#
# For this exercise, answer the questions below given the dataset: https://fred.stlouisfed.org/series/UMTMVS
#
# This dataset is the Value of Manufacturers' Shipments for All Manufacturing Industries.

# %% [markdown]
# **Import any necessary libraries.**

# %%
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# **Read in the data UMTMVS.csv file from the Data folder**

# %%
df = pd.read_csv('UMTMVS.csv')

# %% [markdown]
# **Check the head of the data**

# %%
df.head()
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %%
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %% [markdown]
# **Set the DATE column as the index.**

# %%
df.set_index('DATE',inplace=True)
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %% [markdown]
# **Check the data type of the index.**

# %%
df.index
# Out:
# Index(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#        '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01', '1992-10-01',
#        ...
#        '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'],
#       dtype='object', name='DATE', length=325)

# %%
# Out:
# Index(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#        '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01', '1992-10-01',
#        ...
#        '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'],
#       dtype='object', name='DATE', length=325)

# %% [markdown]
# **Convert the index to be a datetime index. Note, there are many, many correct ways to do this!**

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %%
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %% [markdown]
# **Plot out the data, choose a reasonable figure size**

# %%
df.plot(figsize=(16,5))
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# **What was the percent increase in value from Jan 2009 to Jan 2019?**

# %%
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
(df.loc['2019-01-01']-df.loc['2009-01-01'])/df.loc['2009-01-01']*100
# Out:
# UMTMVS    38.472149
# dtype: float64

# %% [markdown]
# **What was the percent decrease from Jan 2008 to Jan 2009?**

# %%
(df.loc['2009-01-01']-df.loc['2008-01-01'])/df.loc['2008-01-01']*100
# Out:
# UMTMVS   -22.022775
# dtype: float64

# %%
# Out:
# UMTMVS   -22.022775
# dtype: float64

# %% [markdown]
# **What is the month with the least value after 2005?** [HINT](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmin.html)

# %%
df[df.index >= '2005-01-01'].idxmin()

# Otra forma
# df.loc['2005-01-01':].idxmin()
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %%
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %% [markdown]
# **What 6 months have the highest value?**

# %%
df.sort_values('UMTMVS',ascending=False).head(6)
# Out:
#               UMTMVS
# DATE
# 2018-08-01  529157.0
# 2018-10-01  527031.0
# 2018-06-01  525660.0
# 2018-03-01  518285.0
# 2018-09-01  516992.0
# 2014-06-01  516935.0

# %%
# Out:
#               UMTMVS    Yearly Mean
# DATE
# 2018-08-01  529157.0  490453.500000
# 2018-10-01  527031.0  496482.333333
# 2018-06-01  525660.0  483611.000000
# 2018-03-01  518285.0  474351.250000
# 2018-09-01  516992.0  493075.583333

# %% [markdown]
# **How many millions of dollars in value was lost in 2008? (Another way of posing this question is what was the value difference between Jan 2008 and Jan 2009)**

# %%
df.loc['2009-01-01']-df.loc['2008-01-01']
# Out:
# UMTMVS   -95206.0
# dtype: float64

# %%
# Out:
# UMTMVS    95206.0
# dtype: float64

# %% [markdown]
# **Create a bar plot showing the average value in millions of dollars per year**

# %%
df['UMTMVS'].resample('A').mean().plot.bar(figsize=(16,6),title='Average value in millions of dollars per year')

# Otra forma
# df.resample('Y').mean().plot.bar(figsize=(15,8))
# Out:
# /tmp/ipykernel_74105/1395713902.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df['UMTMVS'].resample('A').mean().plot.bar(figsize=(16,6),title='Average value in millions of dollars per year')
# <Axes: title={'center': 'Average value in millions of dollars per year'}, xlabel='DATE'>

# %% [markdown]
# **What year had the biggest increase in mean value from the previous year's mean value? (Lots of ways to get this answer!)**
#
# [HINT for a useful method](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.idxmax.html)

# %%
df2 = df.resample('A').mean()
df2
# Out:
# /tmp/ipykernel_74105/1703606424.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   
# 2012-12-31  474727.333333  484145.416667
# 2013-12-31  484145.416667  490629.916667
# 2014-12-31  490629.916667  459918.333333
# 2015-12-31  459918.333333  446224.500000
# 2016-12-31  446224.500000  467076.333333
# 2017-12-31  467076.333333  499964.166667
# 2018-12-31  499964.166667  466791.000000
# 2019-12-31  466791.000000            NaN

# %%
df2['diff']=df2['aux']-df2['UMTMVS']
df2.head()
# Out:
#                    UMTMVS            aux          diff
# DATE
# 1992-12-31  242002.000000  251708.083333   9706.083333
# 1993-12-31  251708.083333  269842.666667  18134.583333
# 1994-12-31  269842.666667  289973.083333  20130.416667
# 1995-12-31  289973.083333  299765.666667   9792.583333
# 1996-12-31  299765.666667  319558.250000  19792.583333

# %%
df2.sort_values('diff',ascending=False).head(1)
# Out:
#                    UMTMVS            aux      diff
# DATE
# 2010-12-31  409273.083333  457657.833333  48384.75

# %%
# Out:
# Timestamp('2011-12-31 00:00:00', freq='A-DEC')

# %% [markdown]
# **Plot out the yearly rolling mean on top of the original data. Recall that this is monthly data and there are 12 months in a year!**

# %%
df['Yearly Mean'] = df['UMTMVS'].rolling(window=12).mean()
df[['UMTMVS','Yearly Mean']].plot(figsize=(12,5)).autoscale(axis='x',tight=True);

# %% [markdown]
# **BONUS QUESTION (HARD).**
#
# **Some month in 2008 the value peaked for that year. How many months did it take to surpass that 2008 peak? (Since it crashed immediately after this peak) There are many ways to get this answer. NOTE: I get 70 months as my answer, you may get 69 or 68, depending on whether or not you count the start and end months. Refer to the video solutions for full explanation on this.**

# %%
df = pd.read_csv('UMTMVS.csv',index_col='DATE',parse_dates=True)
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
df2008 = df.loc['2008-01-01':'2009-01-01']
df2008.head()
# Out:
#               UMTMVS
# DATE
# 2008-01-01  432307.0
# 2008-02-01  442996.0
# 2008-03-01  474592.0
# 2008-04-01  475667.0
# 2008-05-01  490500.0

# %%
df2008.idxmax()
# Out:
# UMTMVS   2008-06-01
# dtype: datetime64[ns]

# %%
df2008.max()
# Out:
# UMTMVS    510081.0
# dtype: float64

# %%
df_post_peak = df.loc['2008-06-01':]
df_post_peak.head()
# Out:
#               UMTMVS
# DATE
# 2008-06-01  510081.0
# 2008-07-01  476948.0
# 2008-08-01  482530.0
# 2008-09-01  471799.0
# 2008-10-01  450521.0

# %%
df_post_peak[df_post_peak>=510081].dropna()
# Out:
#               UMTMVS
# DATE
# 2008-06-01  510081.0
# 2014-03-01  513700.0
# 2014-06-01  516935.0
# 2014-09-01  512988.0
# 2018-03-01  518285.0
# 2018-05-01  515105.0
# 2018-06-01  525660.0
# 2018-08-01  529157.0
# 2018-09-01  516992.0
# 2018-10-01  527031.0

# %%
len(df.loc['2008-06-01':'2014-03-01'])
# Out:
# 70

# %%
# Out:
# 70

# %% [markdown]
# # GREAT JOB!
